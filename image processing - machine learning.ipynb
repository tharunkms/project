# %%
import os
import warnings
warnings.simplefilter('ignore')

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from skimage.io import imread, imshow
from skimage.transform import resize
from skimage.color import rgb2gray

# %%
henrycavill = os.listdir("C:/Users/kmsth/OneDrive/Pictures/henry cavill")

# %%
rdj = os.listdir("C:/Users/kmsth/OneDrive/Pictures/tony")

# %%
tyler = os.listdir("C:/Users/kmsth/OneDrive/Pictures/tyler")

# %%
limit = 10
henrycavill_images=[None]*limit
j=0
for i in henrycavill:
    if(j<limit):
        henrycavill_images[j]=imread("C:/Users/kmsth/OneDrive/Pictures/henry cavill/"+i)
        j+=1
    else:
        break

# %%
limit = 10
rdj_images=[None]*limit
j=0
for i in rdj:
    if(j<limit):
        rdj_images[j]=imread("C:/Users/kmsth/OneDrive/Pictures/tony/"+i)
        j+=1
    else:
        break

# %%
limit = 10
tyler_images=[None]*limit
j=0
for i in tyler:
    if(j<limit):
        tyler_images[j]=imread("C:/Users/kmsth/OneDrive/Pictures/tyler/"+i)
        j+=1
    else:
        break

# %%
imshow(henrycavill_images[1])

# %%
imshow(rdj_images[1])

# %%
imshow(tyler_images[9])

# %%
tyler_images[4].shape
# Out:
# (662, 572, 3)

# %%
henrycavill_gray=[None]*limit
j=0
for i in henrycavill:
    if(j<limit):
        henrycavill_gray[j]=rgb2gray(henrycavill_images[j])
        j+=1
    else:
        break

# %%
imshow(henrycavill_gray[8])

# %%
rdj_gray=[None]*limit
j=0
for i in rdj:
    if(j<limit):
        rdj_gray[j]=rgb2gray(rdj_images[j])
        j+=1
    else:
        break

# %%
tyler_gray=[None]*limit
j=0
for i in tyler:
    if(j<limit):
        tyler_gray[j]=rgb2gray(tyler_images[j])
        j+=1
    else:
        break

# %%
imshow(rdj_gray[1])

# %%
imshow(tyler_gray[4])

# %%
tyler_gray[4].shape
# Out:
# (662, 572)

# %%
rdj_gray[4].shape
# Out:
# (446, 331)

# %%
henrycavill_gray[4].shape
# Out:
# (163, 310)

# %%
for j in range (10):
    henrycavill=henrycavill_gray[j]
    henrycavill_gray[j]=resize(henrycavill,(512,512))

# %%
for j in range (10):
    rdj=rdj_gray[j]
    rdj_gray[j]=resize(rdj,(512,512))

# %%
for j in range (10):
    tyler=tyler_gray[j]
    tyler_gray[j]=resize(tyler,(512,512))

# %%
imshow(tyler_gray[4])

# %%
tyler_gray[4].shape
# Out:
# (512, 512)

# %%
henrycavill_gray[4].shape
# Out:
# (512, 512)

# %%
len_of_images_henrycavill=len(henrycavill_gray)

# %%
image_size_henrycavill=henrycavill_gray[1].shape

# %%
image_size_henrycavill
# Out:
# (512, 512)

# %%
flatten_size_henrycavill=image_size_henrycavill[0]*image_size_henrycavill[1]

# %%
flatten_size_henrycavill
# Out:
# 262144

# %%
for i in range(len_of_images_henrycavill):
    henrycavill_gray[i]=np.ndarray.flatten(henrycavill_gray[i]).reshape(flatten_size_henrycavill,1)

# %%
henrycavill_gray[4].shape
# Out:
# (262144, 1)

# %%
henrycavill_gray = np.dstack(henrycavill_gray)

# %%
henrycavill_gray
# Out:
# array([[[0.50738732, 0.37254902, 0.52321255, ..., 0.51641997,
#          0.50671081, 0.14885718]],
#
#        [[0.50648352, 0.37254902, 0.52321255, ..., 0.51671841,
#          0.50553091, 0.14827507]],
#
#        [[0.50617715, 0.37254902, 0.52321255, ..., 0.51701686,
#          0.50435102, 0.14769297]],
#
#        ...,
#
#        [[0.620826  , 0.37254902, 0.97474039, ..., 0.69907414,
#          0.49744863, 0.43134542]],
#
#        [[0.61938017, 0.37254902, 0.97478449, ..., 0.69307751,
#          0.49569071, 0.42570398]],
#
#        [[0.61511496, 0.37254902, 0.97482859, ..., 0.68708088,
#          0.49393279, 0.42006254]]])

# %%
henrycavill_gray=np.rollaxis(henrycavill_gray,axis=2,start=0)

# %%
henrycavill_gray.shape
# Out:
# (10, 262144, 1)

# %%
henrycavill_gray=henrycavill_gray.reshape(len_of_images_henrycavill,flatten_size_henrycavill)

# %%
henrycavill_gray.shape
# Out:
# (10, 262144)

# %%
henrycavill_data=pd.DataFrame(henrycavill_gray)

# %%
henrycavill_data
# Out:
#      0         1         2         3         4         5         6       \
# 0  0.507387  0.506484  0.506177  0.507081  0.507985  0.508889  0.509792
# 1  0.372549  0.372549  0.372549  0.372549  0.372549  0.372549  0.372549
# 2  0.523213  0.523213  0.523213  0.523213  0.523213  0.523213  0.523213
# 3  0.865775  0.865439  0.865234  0.865569  0.865904  0.866240  0.866575
# 4  0.792493  0.792493  0.792475  0.791665  0.790576  0.789011  0.788571
# 5  0.888396  0.888396  0.888396  0.888396  0.888396  0.888396  0.888396
# 6  0.433579  0.433579  0.433579  0.433579  0.432499  0.430952  0.429432
# 7  0.516420  0.516718  0.517017  0.516835  0.516536  0.516238  0.515939
# 8  0.506711  0.505531  0.504351  0.503171  0.501991  0.502603  0.503783
# 9  0.148857  0.148275  0.147693  0.147264  0.147846  0.148428  0.149010
#
#      7         8         9       ...    262134    262135    262136    262137  \
# 0  0.510216  0.510636  0.511055  ...  0.581149  0.588697  0.596245  0.603765
# ...

# %%
henrycavill_data["label"]="henrycavill"

# %%
henrycavill_data
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.507387  0.506484  0.506177  0.507081  0.507985  0.508889  0.509792
# 1  0.372549  0.372549  0.372549  0.372549  0.372549  0.372549  0.372549
# 2  0.523213  0.523213  0.523213  0.523213  0.523213  0.523213  0.523213
# 3  0.865775  0.865439  0.865234  0.865569  0.865904  0.866240  0.866575
# 4  0.792493  0.792493  0.792475  0.791665  0.790576  0.789011  0.788571
# 5  0.888396  0.888396  0.888396  0.888396  0.888396  0.888396  0.888396
# 6  0.433579  0.433579  0.433579  0.433579  0.432499  0.430952  0.429432
# 7  0.516420  0.516718  0.517017  0.516835  0.516536  0.516238  0.515939
# 8  0.506711  0.505531  0.504351  0.503171  0.501991  0.502603  0.503783
# 9  0.148857  0.148275  0.147693  0.147264  0.147846  0.148428  0.149010
#
#           7         8         9  ...    262135    262136    262137    262138  \
# 0  0.510216  0.510636  0.511055  ...  0.588697  0.596245  0.603765  0.608030
# ...

# %%
len_of_images_rdj=len(rdj_gray)

# %%
image_size_rdj=rdj_gray[1].shape

# %%
image_size_rdj
# Out:
# (512, 512)

# %%
flatten_size_rdj=image_size_rdj[0]*image_size_rdj[1]

# %%
flatten_size_rdj
# Out:
# 262144

# %%
for i in range(len_of_images_rdj):
    rdj_gray[i]=np.ndarray.flatten(rdj_gray[i]).reshape(flatten_size_rdj,1)

# %%
rdj_gray[4].shape
# Out:
# (262144, 1)

# %%
rdj_gray = np.dstack(rdj_gray)

# %%
rdj_gray
# Out:
# array([[[0.9882502 , 0.15069412, 0.15632158, ..., 0.09223093,
#          0.63722431, 0.02352941]],
#
#        [[0.9882502 , 0.15069412, 0.12918265, ..., 0.09223093,
#          0.63722431, 0.02352941]],
#
#        [[0.9882502 , 0.15069412, 0.13711347, ..., 0.09223093,
#          0.63749352, 0.02352941]],
#
#        ...,
#
#        [[0.13914801, 0.09588876, 0.13718644, ..., 0.07826276,
#          0.29901676, 0.02352941]],
#
#        [[0.13540743, 0.1022394 , 0.1374561 , ..., 0.07826276,
#          0.32779237, 0.02352941]],
#
#        [[0.13509922, 0.10747837, 0.13540418, ..., 0.07826276,
#          0.35590651, 0.02352941]]])

# %%
rdj_gray=np.rollaxis(rdj_gray,axis=2,start=0)

# %%
rdj_gray.shape
# Out:
# (10, 262144, 1)

# %%
rdj_gray=rdj_gray.reshape(len_of_images_rdj,flatten_size_rdj)

# %%
rdj_gray.shape
# Out:
# (10, 262144)

# %%
rdj_data=pd.DataFrame(rdj_gray)

# %%
rdj_data
# Out:
#      0         1         2         3         4         5         6       \
# 0  0.988250  0.988250  0.988250  0.988250  0.988250  0.988250  0.988250
# 1  0.150694  0.150694  0.150694  0.150694  0.150694  0.150694  0.150694
# 2  0.156322  0.129183  0.137113  0.316185  0.579197  0.737135  0.733531
# 3  0.615626  0.615626  0.615626  0.615626  0.615626  0.615626  0.615626
# 4  0.477155  0.476006  0.472589  0.465147  0.459205  0.454339  0.451641
# 5  0.004123  0.004092  0.000565  0.000565  0.000575  0.001056  0.004851
# 6  0.157917  0.157917  0.157917  0.156633  0.154979  0.154914  0.154914
# 7  0.092231  0.092231  0.092231  0.092231  0.092231  0.092355  0.092658
# 8  0.637224  0.637224  0.637494  0.639927  0.641146  0.641146  0.640860
# 9  0.023529  0.023529  0.023529  0.023529  0.023529  0.023529  0.023529
#
#      7         8         9       ...    262134    262135    262136    262137  \
# 0  0.988250  0.988250  0.988250  ...  0.154400  0.155701  0.156697  0.157409
# ...

# %%
rdj_data["label"]="rdj"

# %%
rdj_data
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.988250  0.988250  0.988250  0.988250  0.988250  0.988250  0.988250
# 1  0.150694  0.150694  0.150694  0.150694  0.150694  0.150694  0.150694
# 2  0.156322  0.129183  0.137113  0.316185  0.579197  0.737135  0.733531
# 3  0.615626  0.615626  0.615626  0.615626  0.615626  0.615626  0.615626
# 4  0.477155  0.476006  0.472589  0.465147  0.459205  0.454339  0.451641
# 5  0.004123  0.004092  0.000565  0.000565  0.000575  0.001056  0.004851
# 6  0.157917  0.157917  0.157917  0.156633  0.154979  0.154914  0.154914
# 7  0.092231  0.092231  0.092231  0.092231  0.092231  0.092355  0.092658
# 8  0.637224  0.637224  0.637494  0.639927  0.641146  0.641146  0.640860
# 9  0.023529  0.023529  0.023529  0.023529  0.023529  0.023529  0.023529
#
#           7         8         9  ...    262135    262136    262137    262138  \
# 0  0.988250  0.988250  0.988250  ...  0.155701  0.156697  0.157409  0.157060
# ...

# %%
len_of_images_tyler=len(tyler_gray)
len_of_images_tyler=len(tyler_gray)
image_size_tyler=tyler_gray[1].shape

# %%
flatten_size_tyler = image_size_tyler[0]*image_size_tyler[1]
for i in range(len_of_images_tyler):
    tyler_gray[i] = np.ndarray.flatten(tyler_gray[i]).reshape(flatten_size_tyler,1)
tyler_gray = np.dstack(tyler_gray)
tyler_gray= np.rollaxis(tyler_gray, axis = 2, start = 0)
tyler_gray = tyler_gray.reshape(len_of_images_tyler, flatten_size_tyler)

# %%
tyler_gray.shape
# Out:
# (10, 262144)

# %%
tyler_data=pd.DataFrame(tyler_gray)

# %%
tyler_data
# Out:
#      0         1         2         3         4         5         6       \
# 0  0.068314  0.068962  0.069619  0.069642  0.069017  0.067923  0.067230
# 1  0.269758  0.257572  0.241776  0.233995  0.228169  0.213886  0.194019
# 2  0.220958  0.228247  0.231352  0.230849  0.234827  0.236301  0.233258
# 3  0.196259  0.196499  0.186371  0.176645  0.167382  0.158154  0.148972
# 4  0.657226  0.656788  0.654567  0.654160  0.651794  0.650944  0.651645
# 5  0.054322  0.054322  0.054322  0.054322  0.054322  0.054440  0.054463
# 6  0.547339  0.547339  0.547250  0.546822  0.546684  0.546684  0.546684
# 7  0.813268  0.788885  0.774280  0.763596  0.738739  0.712805  0.691956
# 8  0.269758  0.257572  0.241776  0.233995  0.228169  0.213886  0.194019
# 9  0.232289  0.229281  0.228369  0.231470  0.235366  0.229000  0.228845
#
#      7         8         9       ...    262134    262135    262136    262137  \
# 0  0.069881  0.066344  0.066418  ...  0.287605  0.267823  0.269097  0.282226
# ...

# %%
tyler_data["label"]="tyler"

# %%
tyler_data
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.068314  0.068962  0.069619  0.069642  0.069017  0.067923  0.067230
# 1  0.269758  0.257572  0.241776  0.233995  0.228169  0.213886  0.194019
# 2  0.220958  0.228247  0.231352  0.230849  0.234827  0.236301  0.233258
# 3  0.196259  0.196499  0.186371  0.176645  0.167382  0.158154  0.148972
# 4  0.657226  0.656788  0.654567  0.654160  0.651794  0.650944  0.651645
# 5  0.054322  0.054322  0.054322  0.054322  0.054322  0.054440  0.054463
# 6  0.547339  0.547339  0.547250  0.546822  0.546684  0.546684  0.546684
# 7  0.813268  0.788885  0.774280  0.763596  0.738739  0.712805  0.691956
# 8  0.269758  0.257572  0.241776  0.233995  0.228169  0.213886  0.194019
# 9  0.232289  0.229281  0.228369  0.231470  0.235366  0.229000  0.228845
#
#           7         8         9  ...    262135    262136    262137    262138  \
# 0  0.069881  0.066344  0.066418  ...  0.267823  0.269097  0.282226  0.302645
# ...

# %%
actor = pd.concat([henrycavill_data,rdj_data,tyler_data])

# %%
actor
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.507387  0.506484  0.506177  0.507081  0.507985  0.508889  0.509792
# 1  0.372549  0.372549  0.372549  0.372549  0.372549  0.372549  0.372549
# 2  0.523213  0.523213  0.523213  0.523213  0.523213  0.523213  0.523213
# 3  0.865775  0.865439  0.865234  0.865569  0.865904  0.866240  0.866575
# 4  0.792493  0.792493  0.792475  0.791665  0.790576  0.789011  0.788571
# 5  0.888396  0.888396  0.888396  0.888396  0.888396  0.888396  0.888396
# 6  0.433579  0.433579  0.433579  0.433579  0.432499  0.430952  0.429432
# 7  0.516420  0.516718  0.517017  0.516835  0.516536  0.516238  0.515939
# 8  0.506711  0.505531  0.504351  0.503171  0.501991  0.502603  0.503783
# 9  0.148857  0.148275  0.147693  0.147264  0.147846  0.148428  0.149010
# 0  0.988250  0.988250  0.988250  0.988250  0.988250  0.988250  0.988250
# 1  0.150694  0.150694  0.150694  0.150694  0.150694  0.150694  0.150694
# ...

# %%
from sklearn.utils import shuffle

# %%
actors_indexed = shuffle(actor).reset_index()

# %%
actors_indexed
# Out:
#     index         0         1         2         3         4         5  \
# 0       6  0.157917  0.157917  0.157917  0.156633  0.154979  0.154914
# 1       7  0.092231  0.092231  0.092231  0.092231  0.092231  0.092355
# 2       8  0.506711  0.505531  0.504351  0.503171  0.501991  0.502603
# 3       9  0.148857  0.148275  0.147693  0.147264  0.147846  0.148428
# 4       2  0.220958  0.228247  0.231352  0.230849  0.234827  0.236301
# 5       3  0.615626  0.615626  0.615626  0.615626  0.615626  0.615626
# 6       7  0.516420  0.516718  0.517017  0.516835  0.516536  0.516238
# 7       5  0.004123  0.004092  0.000565  0.000565  0.000575  0.001056
# 8       4  0.477155  0.476006  0.472589  0.465147  0.459205  0.454339
# 9       6  0.433579  0.433579  0.433579  0.433579  0.432499  0.430952
# 10      0  0.507387  0.506484  0.506177  0.507081  0.507985  0.508889
# 11      9  0.023529  0.023529  0.023529  0.023529  0.023529  0.023529
# ...

# %%
actors=actors_indexed.drop(['index'],axis=1)

# %%
actors
# Out:
#            0         1         2         3         4         5         6  \
# 0   0.157917  0.157917  0.157917  0.156633  0.154979  0.154914  0.154914
# 1   0.092231  0.092231  0.092231  0.092231  0.092231  0.092355  0.092658
# 2   0.506711  0.505531  0.504351  0.503171  0.501991  0.502603  0.503783
# 3   0.148857  0.148275  0.147693  0.147264  0.147846  0.148428  0.149010
# 4   0.220958  0.228247  0.231352  0.230849  0.234827  0.236301  0.233258
# 5   0.615626  0.615626  0.615626  0.615626  0.615626  0.615626  0.615626
# 6   0.516420  0.516718  0.517017  0.516835  0.516536  0.516238  0.515939
# 7   0.004123  0.004092  0.000565  0.000565  0.000575  0.001056  0.004851
# 8   0.477155  0.476006  0.472589  0.465147  0.459205  0.454339  0.451641
# 9   0.433579  0.433579  0.433579  0.433579  0.432499  0.430952  0.429432
# 10  0.507387  0.506484  0.506177  0.507081  0.507985  0.508889  0.509792
# 11  0.023529  0.023529  0.023529  0.023529  0.023529  0.023529  0.023529
# ...

# %%
actors.to_csv("C:/Users/kmsth/OneDrive/Documents/image processing - machine learning/Actors.csv")

# %%
x=actors.values[:,:-1]

# %%
y=actors.values[:,-1]

# %%
x
# Out:
# array([[0.15791691176470588, 0.1579169117647059, 0.1579169117647059, ...,
#         0.1342744170843386, 0.14999188983393652, 0.15289014722038716],
#        [0.09223092524509806, 0.09223092524509806, 0.09223092524509804,
#         ..., 0.07826276348039216, 0.07826276348039216,
#         0.07826276348039216],
#        [0.5067108053386913, 0.5055309121098238, 0.5043510188809563, ...,
#         0.4974486273193359, 0.49569070947983684, 0.49393279164033776],
#        ...,
#        [0.8132676652815654, 0.7888854854326628, 0.7742796827836081, ...,
#         0.3985834053184235, 0.39817921568901093, 0.3981792156890109],
#        [0.05432156862745098, 0.05432156862745098, 0.05432156862745098,
#         ..., 0.07561434436274508, 0.07146299632352943,
#         0.060387628676470594],
#        [0.6372243137254903, 0.6372243137254903, 0.637493519155465, ...,
#         0.29901676440669045, 0.32779237497367114, 0.35590651430616194]],
#       dtype=object)

# %%
y
# Out:
# array(['rdj', 'rdj', 'henrycavill', 'henrycavill', 'tyler', 'rdj',
#        'henrycavill', 'rdj', 'rdj', 'henrycavill', 'henrycavill', 'rdj',
#        'henrycavill', 'tyler', 'tyler', 'rdj', 'tyler', 'tyler', 'rdj',
#        'henrycavill', 'henrycavill', 'tyler', 'henrycavill', 'rdj',
#        'tyler', 'tyler', 'henrycavill', 'tyler', 'tyler', 'rdj'],
#       dtype=object)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train
# Out:
# array([[0.8132676652815654, 0.7888854854326628, 0.7742796827836081, ...,
#         0.3985834053184235, 0.39817921568901093, 0.3981792156890109],
#        [0.023529411764705882, 0.023529411764705882, 0.023529411764705882,
#         ..., 0.02352941176470588, 0.023529411764705882,
#         0.023529411764705882],
#        [0.26975813112745095, 0.2575724629720052, 0.2417761274509804, ...,
#         0.047929803921568634, 0.047929803921568634, 0.047929803921568634],
#        ...,
#        [0.2322893208676321, 0.22928070398453962, 0.22836876259726976,
#         ..., 0.3632131938730281, 0.3717609648108644, 0.3675396783825462],
#        [0.9882501960784313, 0.9882501960784313, 0.9882501960784313, ...,
#         0.13914800967347385, 0.1354074297317804, 0.13509921715231502],
#        [0.8657745260081572, 0.8654391019215304, 0.8652336168954887, ...,
#         0.6384968103909959, 0.6373881322090298, 0.6355783781178792]],
#       dtype=object)

# %%
y_train
# Out:
# array(['tyler', 'rdj', 'tyler', 'henrycavill', 'rdj', 'tyler', 'rdj',
#        'tyler', 'rdj', 'henrycavill', 'rdj', 'rdj', 'henrycavill',
#        'tyler', 'rdj', 'henrycavill', 'henrycavill', 'rdj', 'tyler',
#        'henrycavill', 'rdj', 'tyler', 'rdj', 'henrycavill'], dtype=object)

# %%
from sklearn import svm

# %%
clf = svm.SVC()

# %%
clf.fit(x_train, y_train)
# Out:
# SVC()

# %%
y_pred = clf.predict(x_test)

# %%
y_pred
# Out:
# array(['rdj', 'tyler', 'tyler', 'henrycavill', 'rdj', 'tyler'],
#       dtype=object)

# %%
for i in range(6):
    predicted_images = (np.reshape(x_test[i],(512,512)).astype(np.float64))
    plt.title('predicted label: {0}'.format(y_pred[i]))
    plt.imshow(predicted_images, interpolation='nearest', cmap='gray')
    plt.show()

# %%
from sklearn import metrics

# %%
accuracy=metrics.accuracy_score(y_test,y_pred)

# %%
accuracy
# Out:
# 0.6666666666666666

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[1, 2, 0],
#        [0, 0, 0],
#        [0, 0, 3]], dtype=int64)
